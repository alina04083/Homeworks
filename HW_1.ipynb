# %% [markdown]
# <a href="https://colab.research.google.com/github/alina04083/Homeworks/blob/main/HW_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.

# %%
x=float(input('x='))
y=x-(x**3)/3+(x**5)/5
print(y)
# Out:
# x=2
# 5.733333333333334

# %% [markdown]
# 2.

# %%
x=float(input('x='))
y=float(input('y='))
z=float(input('z='))
import math
w=(3+(math.e**(y-1)))/(1+(x**2)*(math.fabs(y-(math.tan(z)))))
print(w)
# Out:
# x=2
# y=2
# z=2
# 0.3223354245261413

# %% [markdown]
# 3.

# %%
a=float(input('a='))
b=float(input('b='))
n=float(input('n='))
import math
x=((a**3)+(b**3))/n
y=math.sqrt((math.fabs(a))*(math.fabs(b)))
print(x, y)
# Out:
# a=2
# b=3
# n=2
# 17.5 2.449489742783178

# %% [markdown]
# 4.

# %%
x=int(input('x='))
a=x//10
b=x%10
s=b*10+a
print(s)
# Out:
# x=25
# 52

# %% [markdown]
# 5.

# %%
x1=int(input('x1='))
y1=int(input('y1='))
x2=int(input('x2='))
y2=int(input('y2='))
z = (x1 == x2) or (y1 == y2)
print(z)
# Out:
# x1=4
# y1=5
# x2=3
# y2=5
# True
