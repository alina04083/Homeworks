# %% [markdown]
# <a href="https://colab.research.google.com/github/alina04083/Homeworks/blob/main/%D0%97%D0%B0%D0%BD%D1%8F%D1%82%D0%B8%D0%B5_04_04_(%D0%BF%D0%BE%D0%B2%D1%82%D0%BE%D1%80).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Группа Begin**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a=int(input('a='))
P=4*a
print(P)
# Out:
# a=4
# 16

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
A=float(input('A='))
B=float(input('B='))
C=float(input('C='))
D=B
B=A
A=C
C=D
print(A, B, C)
# Out:
# A=6
# B=7
# C=4
# 4.0 6.0 7.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x=float(input('x='))
a=float(input('a='))
y=float(input('y='))
n=a/x
s=n*y
print(n, s)
# Out:
# x=5
# a=100
# y=6
# 20.0 120.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
v1=float(input('v1=')) #скорость первого
v2=float(input('v2=')) #скорость второго
s=float(input('s=')) #расстояние
t=float(input('t=')) #время
p=t*(v1+v2) #общее расстояние
print(t+p)
# Out:
# v1=20
# v2=30
# s=6
# t=8
# 408.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from math import sqrt
A=float(input('A='))
B=float(input('B='))
C=float(input('C='))
D=B**(2)-4*A*C
x1=(-B+sqrt(D))/(2*A)
x2=(-B-sqrt(D))/(2*A)
print(x1, x2)
# Out:
# A=1
# B=4
# C=2
# -0.5857864376269049 -3.414213562373095

# %% [markdown]
# **Группа Integer**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a=int(input('a='))
b=a//1024
print(b)
# Out:
# a=120000000
# 117187

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a=int(input('a='))
b=a//1000
c=b%10
print(c)
# Out:
# a=1234567
# 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
N=int(input('N='))
a=N%3600
b=a//60
print(b, ' minutes ')
# Out:
# N=7500
# 5  minutes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
K=int(input('K=')) # от 1 до 365
N=int(input('N=')) # от 1 до 7
s=(K-1) % 7 + N
print(s)
# Out:
# K=203
# N=3
# 9

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
A=int(input('A='))
B=int(input('B='))
C=int(input('C='))
S1=A*B #площадь прямоугольника
n=A//C #количество квадратов по длине
m=B//C #количество квадратов по ширине
S2=n*m*(C**2) #площадь, которую занимают квадраты
print(S1-S2)
# Out:
# A=5
# B=6
# C=2
# 6

# %% [markdown]
# **Группа Boolean**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
A=int(input('A='))
x=A%2==0
print(x)
# Out:
# A=67
# False

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
A=int(input('A='))
B=int(input('B='))
C=int(input('C='))
(A>0 and B>0) or (A>0 and C>0) or (B>0 and C>0)
# Out:
# A=4
# B=-4
# C=-4
# False

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a=int(input('a='))
b1=a//100
b2=(a%100)//10
b3=a%10
b1!=b2 and b2!=b3 and b1!=b3
# Out:
# a=456
# True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Группа If**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Группа For**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Группа While**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
