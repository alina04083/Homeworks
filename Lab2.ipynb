# %% [markdown]
# <a href="https://colab.research.google.com/github/alina04083/Homeworks/blob/main/Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a=int(input('a='))
b=int(input('b='))
c=int(input('c='))
k=0
if a>0:
  k=k+1
if b>0:
  k=k+1
if c>0:
  k=k+1

r=0
if a<0:
  r=r+1
if b<0:
  r=r+1
if c<0:
  r=r+1

print(k, r, 3-k-r)
# Out:
# a=2
# b=-4
# c=0
# 1 1 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a=float(input('a='))
b=float(input('b='))
if a>b:
  print(a)
else:
  print(b)
# Out:
# a=2
# b=10
# 10

# %%
a=float(input('a='))
b=float(input('b='))
mx=a
if mx<b:
  mx=b
print(mx)
# Out:
# a=4
# b=6
# 6.0

# %%
a=float(input('a='))
b=float(input('b='))
c=float(input('c='))
mx=a
if mx<b:
  mx=b
if mx<c:
  mx=c
print(mx)
# Out:
# a=1
# b=2
# c=3
# 3.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a=float(input('a='))
b=float(input('b='))
c=float(input('c='))
mx=a
if mx<b:
  mx=b
if mx<c:
  mx=c
mn=a
if mn>b:
  mn=b
if mn>c:
  mn=c
s=(a+b+c)-mx-mn
print(s)
# Out:
# a=6
# b=4
# c=7
# 6.0

# %%
a=float(input('a='))
b=float(input('b='))
c=float(input('c='))
s=(a+b+c)-max(a,b,c)-min(a,b,c)
print(s)
# Out:
# a=5
# b=3
# c=7
# 5.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a=int(input('a='))
b=int(input('b='))
c=int(input('c='))
k=0
if a==b and b!=c:
  k=3
if a==c and c!=b:
  k=2
if b==c and a!=c:
  k=1
print(k)
# Out:
# a=5
# b=2
# c=2
# 1
