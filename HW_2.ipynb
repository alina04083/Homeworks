# %% [markdown]
# <a href="https://colab.research.google.com/github/alina04083/Homeworks/blob/main/HW_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.

# %%
x=float(input('x='))
f=0
if x<=7:
  f=-3*x+9
else:
  f=1/(x-7)
print(f)
# Out:
# x=5
# -6.0

# %% [markdown]
# 2.

# %%
x=float(input('x='))
y=float(input('y='))
if x>0 and y>0:
  print(1)
elif x>0 and y<0:
  print(2)
elif x<0 and y<0:
  print(3)
else:
  print(4)
# Out:
# x=-4
# y=4
# 4

# %% [markdown]
# 3.

# %%
a=float(input('a='))
b=float(input('b='))
c=float(input('c='))
import math
if a>=b and b>=c:
  print(a*2, b*2, c*2)
else:
  print(math.fabs(a),math.fabs(b),math.fabs(c))
# Out:
# a=5
# b=-2
# c=6
# 5.0 2.0 6.0

# %% [markdown]
# 4.

# %%
import math
r=float(input('r=')) # радиус круга
a=float(input('a=')) # сторона квадрата
S1 = 2*math.pi*r
S2 = a**2
if S1>S2:
  print('круг')
else:
  print('квадрат')
# Out:
# r=3
# a=5
# квадрат

# %% [markdown]
# 5. a)

# %%
k=int(input('k='))
s=(k-1)%7+1
if s==1:
  print('понедельник')
if s==2:
  print('вторник')
if s==3:
  print('среда')
if s==4:
  print('четверг')
if s==5:
  print('пятница')
if s==6:
  print('суббота')
if s==7:
  print('воскресенье')
# Out:
# k=75
# пятница

# %% [markdown]
# 5. б)

# %%
k=int(input('k='))
d=int(input('d='))
s=(k-1)%7+d
print(s)
# Out:
# k=29
# d=3
# 3
