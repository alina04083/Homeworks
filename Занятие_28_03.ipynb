# %% [markdown]
# <a href="https://colab.research.google.com/github/alina04083/Homeworks/blob/main/%D0%97%D0%B0%D0%BD%D1%8F%D1%82%D0%B8%D0%B5_28_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a=int(input('a='))
b=int(input('b='))
k=0
while a>=b:
  a=a-b
  k=k+1
print(k,a)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n=int(input('n='))
k=0
while n>3: #делит пока число больше 3, только больше 3, 3 не включается
  n=n/3
z=n==3.0
print(z)
# Out:
# n=27
# True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
S=1000
P=float(input('p='))
k=0
while S<1100:
  x=(S*P)/100
  S=S+x
  k=k+1
print(k, S)
# Out:
# p=3
# 4 1125.50881

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
s=10
k=1
s1=S
p=float(input('p='))
while s1<200:
  x=(s*p)/100
  s=s+x
  s1=s1+s
  k=k+1
print(k,s1)
# Out:
# 5
# 1 1125.50881

# %%
k=1
while k<=10:
  print('Alina', 'Daniil', end=' ')
  k=k+1
# Out:
# Alina Daniil Alina Daniil Alina Daniil Alina Daniil Alina Daniil Alina Daniil Alina Daniil Alina Daniil Alina Daniil Alina Daniil

# %% [markdown]
# Задача: получить ноль

# %%
x=int(input('x=')
S=x
while x!=0:
    s=s+x
    x=int(input('x='))
print(s)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n=int(input())
while n!=0:
  print(n%10)
  n=n//10
# Out:
# 256
# 6
# 5
# 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n=int(input())
s=0
p=1
while n!=0:
  t=n%10
  s=s+t
  p=p*t
  n=n//10
print(s,p)
# Out:
# 5553
# 18 375

# %% [markdown]
# **Фибоначчи**
# (f1 становится f2, f2 - сумма предыдущих 2 значений)**bold text**

# %%
n=int(input())
f1=1
f2=1
print(f1,f2, end=' ')
k=2 #количество
while k<n:
  h=f1+f2
  print(h, end=' ')
  f1=f2
  f2=h
  k=k+1
# Out:
# 4
# 1 1 2 3

# %% [markdown]
# FOR

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
K=int(input('K='))
N=int(input('N='))
for i in range(1, N+1): #начало интервала входит, конец не входит, поэтому делаем +1
  print(k, end='\t')

# %%
N=int(input('N='))
for i in range(1, N+1):
  print('Alina', end='\t') # "\t" - пробел между tab,"\n" - enter, ' ' - пробел между в одной строке
# Out:
# N=6
# Alina	Alina	Alina	Alina	Alina	Alina

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x=float(input('x='))
for i in range(1, 11):
  y=i*x
  print(i, 'kg konfetik =', y, 'R.')
# Out:
# x=4.8
# 1 kg konfetik = 4.8 R.
# 2 kg konfetik = 9.6 R.
# 3 kg konfetik = 14.399999999999999 R.
# 4 kg konfetik = 19.2 R.
# 5 kg konfetik = 24.0 R.
# 6 kg konfetik = 28.799999999999997 R.
# 7 kg konfetik = 33.6 R.
# 8 kg konfetik = 38.4 R.
# 9 kg konfetik = 43.199999999999996 R.
# 10 kg konfetik = 48.0 R.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
A=int(input('A='))
B=int(input('B='))
for i in range(A+1, B):
  print(i, end=' ')
# Out:
# A=3
# B=9
# 4 5 6 7 8

# %%
A=int(input('A='))
B=int(input('B='))
for i in range(B-1,A,-1): #-1 - это шаг приращения
  print(i, end=' ')
# Out:
# A=5
# B=10
# 9 8 7 6

# %%
for i in range(2, 21, 2): #последнее значение - это шаг приращения
  print(i, end=' ')

# %% [markdown]
# **Задача**: Вывести, является ли заданное число простым

# %%
n=int(input())
y = True
for i in range(2, n//2+1): # чтобы половина вошла в интервал
  if n % i == 0:
    y = False
    break
print(y)
# Out:
# 17
# True
