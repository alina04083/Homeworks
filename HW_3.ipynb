# %% [markdown]
# <a href="https://colab.research.google.com/github/alina04083/Homeworks/blob/main/HW_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from math import pow, factorial
x=float(input())
n=int(input())
s=0
z=1
for i in range (1, n+1):
  j=2*i-1
  s=s+(pow(x,j)/factorial(j))*z
  z=-z
print(s)

# %% [markdown]
# 1)

# %%
for i in range(1,32):
  for j in range(1,16):
    if (i*2+j*4)==64:
      print(i,' gose ',j, ' rabbits ')
# Out:
# 2  gose  15  rabbits
# 4  gose  14  rabbits
# 6  gose  13  rabbits
# 8  gose  12  rabbits
# 10  gose  11  rabbits
# 12  gose  10  rabbits
# 14  gose  9  rabbits
# 16  gose  8  rabbits
# 18  gose  7  rabbits
# 20  gose  6  rabbits
# 22  gose  5  rabbits
# 24  gose  4  rabbits
# 26  gose  3  rabbits
# 28  gose  2  rabbits
# 30  gose  1  rabbits

# %% [markdown]
# 2)

# %%
x=float(input('x='))
p=1
for i in range(1,n+1):
  p=p*i # факториал
for i in range(3,13,2):
  y=x-(x**i)/(x)
  print(y)
# Out:
#   File "<ipython-input-4-e1c50962db11>", line 6
#     y=x-(x**i)/(i!)
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# 3)

# %%
e=10**(-3)
n=float(input('n='))

# %% [markdown]
# 4)

# %%
S=0
N=int(input('N='))
for i in range(0,N):
  a=float(input('a='))
  S=S*int(a)
  x = float(a)-int(a)
  print(x)
print(S)
# Out:
# N=5.4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-275a83ea4c88> in <cell line: 0>()
#       1 S=0
# ----> 2 N=int(input('N='))
#       3 for i in range(0,N):
#       4   a=float(input('a='))
#       5   S=S*int(a)
#
# ValueError: invalid literal for int() with base 10: '5.4'
